# %% [markdown]
# ## This page lists the days of class and associated topics topics thhat we will cover on those days. If there is no topic on a day it might happen that the exam preparation is listed. I might update this only a few days in advance.

# %% [markdown]
# ## Class schedule

# %% [markdown]
# ### <2021-01-12 Tue 09:30>  Introduction  [[./lectures/00-intro.org]]

# %% [markdown]
# ### <2021-01-14 Thu 09:30>  Python/Jupyter [[./lectures/01-jupyter.org]]

# %% [markdown]
# ### <2021-01-19 Tue 09:30>  Mathematical modelling [[./lectures/01-modelling.org]]

# %% [markdown]
# ### <2021-01-21 Thu 09:30>  First principle modelling [[./lectures/02-modelling.org]]

# %% [markdown]
# ### <2021-01-26 Tue 09:30>  Integration of models given by first order ordinary differential equations and numerical integration [[./lectures/03-fode-1.org]]

# %% [markdown]
# ### <2021-01-28 Thu 09:30>  Systems of first-order differential equations [[./lectures/04-fode-2.org]]

# %% [markdown]
# ### <2021-02-02 Tue 09:30>  Linear systems [[./lectures/05-Lin-1.org]]

# %% [markdown]
# ### <2021-02-04 Thu 09:30>  Basic Models in Chemical Engineering [[./lectures/06-Lin-2.org]]

# %% [markdown]
# ### <2021-02-09 Tue 09:30>  Preparation Exam

# %% [markdown]
# ### <2021-02-11 Thu 09:30>  Exam I

# %% [markdown]
# ### <2021-02-16 Tue 09:30>  Reading Week

# %% [markdown]
# ### <2021-02-18 Thu 09:30>  Reading Week

# %% [markdown]
# ### <2021-02-23 Tue 09:30>  Continuous and discrete models and representation [[./lectures/07-Cont-Discr-1.org]]

# %% [markdown]
# ### <2021-02-25 Thu 09:30>  Time delay systems [[./lectures/07-Cont-Discr-2.org]]

# %% [markdown]
# ### <2021-03-02 Tue 09:30>  Transfer function models [[./lectures/08-Transfer-function-01.org]]

# %% [markdown]
# ### <2021-03-04 Thu 09:30>  Transfer function link to State Space [[./lectures/08-Transfer_function-02.org]]

# %% [markdown]
# ### <2021-03-09 Tue 09:30>  Mathematical model propertiese, controllability and observability [[./lectures/09-Linear-System-properties.org]]

# %% [markdown]
# ### <2021-03-11 Thu 09:30>  Discrete based models [[./lectures/10-discrete-Linear-System-setting.org]]

# %% [markdown]
# ### <2021-03-16 Tue 09:30>  Discrete model response and properties [[./lectures/11-discrete-system-setting-response.org]]

# %% [markdown]
# ### <2021-03-18 Thu 09:30>  Preparation II

# %% [markdown]
# ### <2021-03-23 Tue 09:30>  Exam II

# %% [markdown]
# ### <2021-03-25 Thu 09:30>  Linear regression I [[./lectures/12-linear-regression.org]]

# %% [markdown]
# ### <2021-03-30 Tue 09:30>  Least square estimation [[./lectures/13-least-square-estimation.org]]

# %% [markdown]
# ### <2021-04-01 Thu 09:30>  System identification [[./lectures/14-system-identification.org]]

# %% [markdown]
# ### <2021-04-06 Tue 09:30>  Principal Component Analysis [[./lectures/15-PCA.org]]

# %% [markdown]
# ### <2021-04-08 Thu 09:30>  Final Exam Preparation

# %% [markdown]
# ### <2021-04-13 Tue 09:30>  Final material summary and missing lectures

# %% [markdown]
# ### <2021-04-15 Thu 09:30>  Final material summary and missing lectures
